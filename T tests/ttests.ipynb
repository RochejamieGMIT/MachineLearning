# %% [markdown]
# # Normal probability Funciton
#
# $ f(x) = \frac{1}{\sigma \sqrt{2 \pi}} e^{- \frac{1}{2} \big ( \frac {x - \mu}{\sigma} \big) ^2}  $

# %%
import numpy as np

def normal_pdf (x, mu=0.0, sigma=1.0):
    #Answer A*B
    A = 1.0/(sigma *np.sqrt(2.0*np.pi))
    B = np.exp(-0.5*((x-mu)/sigma)**2)
    return A*B

# %%
normal_pdf(0.0,mu=-0.0,sigma=np.sqrt(0.2))
# Out:
# 0.8920620580763857

# %% [markdown]
# ## Plots
#
# ![normal PDF](https://upload.wikimedia.org/wikipedia/commons/thumb/7/74/Normal_Distribution_PDF.svg/330px-Normal_Distribution_PDF.svg.png)

# %%
# blank plot
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
#
x = np.linspace(-5.0,5.0,1001)

# plot values

for mu,sigma2 in[[0.0,0.2],[0.0,1.0],[0.0,5.0],[-2.0,0.5]]:
    y = normal_pdf(x,mu=mu,sigma=np.sqrt(sigma2))
    ax.plot(x,y,label=f'$\mu {mu},\sigma^2 {sigma2}$')

ax.legend()
ax.grid()

# %% [markdown]
# # Area under the curve

# %%
fig, ax = plt.subplots(figsize=(12,6))
# PDF STD normal dist
x = np.linspace(-4.0,4.0,1001)

# plot values

for mu,sigma2 in[[0.0,1.0]]:
    y = normal_pdf(x,mu=mu,sigma=np.sqrt(sigma2))
    ax.plot(x,y,label=f'$\mu {mu},\sigma^2 {sigma2}$')
#add x axis
ax.axhline(0.0,color="black")

ax.vlines([-1.0,1],0.0,0.4,color="black")

x_interval = np.linspace(-1.0,1.0,101)
#shade the area under the blue curve
ax.fill_between(x_interval,normal_pdf(x_interval),color="green",alpha=0.4)

ax.legend()

# %%
# the intersection of the gray and blue lines

print(f'(-1.0,{normal_pdf(-1.0)})')
print(f'(1.0,{normal_pdf(1.0)})')
# Out:
# (-1.0,0.24197072451914337)
# (1.0,0.24197072451914337)

# %% [markdown]
# # Normal Data

# %%
# generate Random normal Data

random_data = np.random.standard_normal(100000)

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.hist(random_data, bins=40,density=True)

#plot the pdf for std normal dist

mu,sigma2 = 0.0,1.0

y = normal_pdf(x,mu=mu,sigma=np.sqrt(sigma2))
ax.plot(x,y,label=f'$\mu {mu},\sigma^2 {sigma2}$')

# %% [markdown]
# # Sampling Distribution

# %%
# generate Random normal Data

random_data = np.random.standard_normal((10000,25))

random_data
# Out:
# array([[-1.37244044,  0.48441349,  1.32604301, ...,  0.73475716,
#          0.52382445, -0.57305786],
#        [ 1.36285642,  0.66180999,  0.43064692, ...,  0.49158645,
#         -2.20027837,  1.32220908],
#        [ 1.35188461,  0.4567217 ,  0.84786008, ..., -0.81522451,
#         -0.93808232, -0.90618513],
#        ...,
#        [-1.05649851,  0.72233545,  0.52612212, ..., -0.34372598,
#          1.31424709,  0.96493107],
#        [ 1.82251195,  1.50582598, -0.17314035, ..., -1.66595116,
#          0.75940983,  0.41906745],
#        [ 0.61396227,  0.44879203,  1.7844725 , ...,  0.1835724 ,
#         -1.3445924 ,  1.20013999]])

# %%
# create empty figure

fig, ax = plt.subplots(figsize=(12,6))

#histogram mean 
ax.hist(random_data.mean(axis=1),bins=30,density=True)

y = normal_pdf(x)
ax.plot(x,y,label=f'$\mu {mu},\sigma^2 {sigma2}$')

# %%
# create empty figure

fig, ax = plt.subplots(figsize=(12,6))

#histogram mean 
ax.hist(random_data.mean(axis=1),bins=30,density=True)

x = np.linspace(-4.0,4,1001)
y = normal_pdf(x)
ax.plot(x,y)


y = normal_pdf(x,mu=0.0,sigma=0.2)
ax.plot(x,y)

# %% [markdown]
# # Random Normal

# %%
# Random mean
random_mu = np.random.uniform(-3.0,3.0)

##random_mu

# %%
# Generate random normal data with unknown mu 

random_data = np.random.normal(random_mu,1.0,(10000,25))

# %%
# create empty figure

fig, ax = plt.subplots(figsize=(12,6))

#histogram mean 
ax.hist(random_data.mean(axis=1),bins=30,density=True)
# Out:
# (array([1.84139051e-03, 1.84139051e-03, 3.68278101e-03, 1.10483430e-02,
#         3.86692006e-02, 1.17848992e-01, 1.60200974e-01, 2.79891357e-01,
#         4.34568159e-01, 7.62335669e-01, 1.07537206e+00, 1.41234652e+00,
#         1.62778921e+00, 1.93898420e+00, 2.02921234e+00, 1.90952195e+00,
#         1.82850077e+00, 1.48600214e+00, 1.12693099e+00, 8.61770756e-01,
#         5.67148276e-01, 3.36974462e-01, 1.84139051e-01, 1.25214554e-01,
#         4.05105911e-02, 2.76208576e-02, 1.10483430e-02, 7.36556202e-03,
#         1.84139051e-03, 3.68278101e-03]),
#  array([-2.27581767, -2.22151089, -2.1672041 , -2.11289732, -2.05859053,
#         -2.00428374, -1.94997696, -1.89567017, -1.84136339, -1.7870566 ,
#         -1.73274981, -1.67844303, -1.62413624, -1.56982946, -1.51552267,
#         -1.46121588, -1.4069091 , -1.35260231, -1.29829553, -1.24398874,
#         -1.18968195, -1.13537517, -1.08106838, -1.0267616 , -0.97245481,
#         -0.91814802, -0.86384124, -0.80953445, -0.75522767, -0.70092088,
#         -0.64661409]),
#  <BarContainer object of 30 artists>)

# %%
# estimate randome nu from hist
random_mu
# Out:
# -1.4782272673188859

# %%
# Random sample of 50 
sample = np.random.normal(random_mu,1.0,50)

sample
# Out:
# array([-3.09906739, -3.29534028, -2.8728688 , -3.28372115, -0.96883246,
#        -1.13312667, -2.59722411, -1.81120233, -1.82040008,  0.30226644,
#        -1.23552147, -2.78856183,  0.49235111, -1.6310836 , -2.79727749,
#        -2.11916629, -1.08184374, -1.45601937, -3.74435935, -0.50294959,
#        -0.72864481, -1.27655971, -0.921246  , -1.85608789, -1.37637239,
#        -1.32751649,  0.25706046, -1.09241526, -0.9753374 , -1.10772996,
#        -1.69242562, -0.80739937, -2.2969515 , -1.11643585, -2.65599732,
#        -2.88963698, -1.37607842, -2.48218564, -1.49419127, -0.04196382,
#        -2.48071575, -0.78263652, -0.91217021, -2.29039891,  0.17795065,
#        -1.2457752 , -1.76677905, -1.08156271, -0.45680421,  0.5070991 ])

# %%
# calc mean

sample.mean()
# Out:
# -1.5006771291616736
